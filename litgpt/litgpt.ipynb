# %%
#!git clone https://github.com/Lightning-AI/litgpt.git
# !git clone https://github.com/turing-science/litgpt
# %cd litgpt
# !pip install -e '.[all]'
# Out:
# Cloning into 'litgpt'...
# remote: Enumerating objects: 11804, done.
# remote: Counting objects: 100% (191/191), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 11804 (delta 137), reused 48 (delta 48), pack-reused 11613 (from 3)
# Receiving objects: 100% (11804/11804), 4.92 MiB | 16.16 MiB/s, done.
# Resolving deltas: 100% (8372/8372), done.
# /content/litgpt
# Obtaining file:///content/litgpt
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 4.9 MB/s eta 0:00:00
# ...
# WARNING: litgpt 0.5.12 does not provide the extra 'all'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.3/263.3 kB 22.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.5/228.5 kB 26.2 MB/s eta 0:00:00
# ...

# %%
# !litgpt download list
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   _C._set_float32_matmul_precision(precision)
# Please specify --repo_id <repo_id>. Available values:
# allenai/OLMo-1B-hf
# allenai/OLMo-2-1124-13B
# allenai/OLMo-2-1124-13B-DPO
# allenai/OLMo-2-1124-13B-Instruct
# allenai/OLMo-2-1124-13B-SFT
# allenai/OLMo-2-1124-7B
# allenai/OLMo-2-1124-7B-DPO
# allenai/OLMo-2-1124-7B-Instruct
# allenai/OLMo-2-1124-7B-SFT
# allenai/OLMo-7B-hf
# ...

# %%
# !litgpt download HuggingFaceTB/SmolLM2-135M-Instruct
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   _C._set_float32_matmul_precision(precision)
# Setting HF_HUB_ENABLE_HF_TRANSFER=1
# config.json: 100% 861/861 [00:00<00:00, 4.58MB/s]
# generation_config.json: 100% 132/132 [00:00<00:00, 1.18MB/s]
# model.safetensors: 100% 269M/269M [00:02<00:00, 93.7MB/s]
# tokenizer.json: 2.10MB [00:00, 119MB/s]
# tokenizer_config.json: 3.76kB [00:00, 19.2MB/s]
# ...

# %%
'''!python3 /content/litgpt/litgpt/__main__.py finetune_lora HuggingFaceTB/SmolLM2-135M-Instruct \
  --data Alpaca'''

# !python3 /content/litgpt/litgpt/__main__.py finetune_lora HuggingFaceTB/SmolLM2-135M-Instruct \
  --data FLAN
# Out:
# /content/litgpt/litgpt/__main__.py:66: JsonargparseDeprecationWarning:
#     By default only one JsonargparseDeprecationWarning per type is shown. To see all warnings set environment
#     variable JSONARGPARSE_DEPRECATION_WARNINGS=all and to disable the warnings set
#     JSONARGPARSE_DEPRECATION_WARNINGS=off.
#
#   set_docstring_parse_options(attribute_docstrings=True)
# /content/litgpt/litgpt/__main__.py:66: JsonargparseDeprecationWarning:
#     set_docstring_parse_options was deprecated in v4.39.0 and will be removed in v5.0.0. Docstring parse options
#     should now be set using function set_parsing_settings.
#
#   set_docstring_parse_options(attribute_docstrings=True)
# /content/litgpt/litgpt/__main__.py:67: JsonargparseDeprecationWarning:
#     set_config_read_mode was deprecated in v4.39.0 and will be removed in v5.0.0. Optional config read modes
#     should now be set using function set_parsing_settings.
#
#   set_config_read_mode(urls_enabled=True)
# ...

# %% [markdown]
# Archive from 18/1

# %%
# !python3 /content/litgpt/litgpt/__main__.py finetune_lora HuggingFaceTB/SmolLM2-135M-Instruct \
  --data Alpaca
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 5 | iter 243861 step 15241 | loss train: 1.241, val: 1.186 | iter time: 144.97 ms
# Epoch 5 | iter 243862 step 15241 | loss train: 1.222, val: 1.186 | iter time: 147.14 ms
# Epoch 5 | iter 243863 step 15241 | loss train: 1.263, val: 1.186 | iter time: 146.29 ms
# Epoch 5 | iter 243864 step 15241 | loss train: 1.323, val: 1.186 | iter time: 145.20 ms
# Epoch 5 | iter 243865 step 15241 | loss train: 1.360, val: 1.186 | iter time: 142.48 ms
# Epoch 5 | iter 243866 step 15241 | loss train: 1.366, val: 1.186 | iter time: 142.59 ms
# Epoch 5 | iter 243867 step 15241 | loss train: 1.379, val: 1.186 | iter time: 145.54 ms
# Epoch 5 | iter 243868 step 15241 | loss train: 1.358, val: 1.186 | iter time: 144.78 ms
# Epoch 5 | iter 243869 step 15241 | loss train: 1.332, val: 1.186 | iter time: 145.19 ms
# Epoch 5 | iter 243870 step 15241 | loss train: 1.310, val: 1.186 | iter time: 143.61 ms
# ...

# %%
# !pip install 'litgpt[extra]'

# %%
# from litgpt import LLM

# llm = LLM.load("microsoft/phi-2")
# text = llm.generate("Fix the spelling: Every fall, the familee go to the mountains.")
# print(text)
# Corrected Sentence: Every fall, the family goes to the mountains.

# %%
# !litgpt finetune_lora stabilityai/stablelm-base-alpha-3b \
#   --data Alpaca

# %%
# '''!litgpt finetune_lora HuggingFaceTB/SmolLM-135M-Instruct \
#   --data Alpaca'''
# !litgpt finetune_lora meta-llama/Llama-3.2-1B --data Alpaca
